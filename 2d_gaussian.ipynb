# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# This is similar to the code from lecture 1
# to sample from a 2D Gaussian Distribution
mean = [0,0]
cov = [[1, 1.5], [1.5, 5]]
# Fix random seed to get consistent results
np.random.seed(1024)
X = np.random.multivariate_normal(mean, cov, 1000)
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
# Out:
# (-10, 10)

# %%
# TODO: Report the estimate mean and covariance
# of the sampled points
print("Answer: Yes,the x-coordinates of the 1000 points follows some Gaussian distribution.\n")
mean = np.mean(X)
print("Estimate Mean:",mean,"\n")
cov = np.cov(X.T)
print("Estimate Covariance:\n",cov)
# Out:
# Answer: Yes,the x-coordinates of the 1000 points follows some Gaussian distribution.
#
# Estimate Mean: 0.03586188161776394
#
# Estimate Covariance:
#  [[1.03574467 1.56979754]
#  [1.56979754 5.08040865]]

# %%
# TODO: Plot the histogram for the x-coordinates of X
# and y-coordinates of X respectively.
# You can use the plt.hist() function
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=False)

# We can set the number of bins with the `bins` kwarg
bins = 20
axs[0].hist(X[:,0], bins)
axs[1].hist(X[:,1], bins)
# Out:
# (array([  1.,   2.,   3.,   9.,  16.,  29.,  50.,  60., 105., 117., 138.,
#         141., 107.,  80.,  68.,  39.,  23.,   6.,   3.,   3.]),
#  array([-8.09073464, -7.33086975, -6.57100486, -5.81113997, -5.05127508,
#         -4.29141019, -3.53154531, -2.77168042, -2.01181553, -1.25195064,
#         -0.49208575,  0.26777914,  1.02764403,  1.78750892,  2.54737381,
#          3.3072387 ,  4.06710359,  4.82696848,  5.58683337,  6.34669825,
#          7.10656314]),
#  <a list of 20 Patch objects>)

# %%
# TODO: Are the x-coordinates of X samples from
# some Gaussian distribution?
# If so, estimate the mean and variance.
# Do the same for the y-coordinates.

mean_x = np.mean(X[:,0])
print("Mean of X:",mean_x,"\n")
var_x = np.var(X[:,0])
print("Variance of X:",var_x,"\n")
mean_y = np.mean(X[:,1])
print("Mean of X:",mean_y,"\n")
var_y = np.var(X[:,1])
print("Variance of X:",var_y,"\n")

# TODO: Generate a new 2D scatter plot of 1000 points,
# such that the x-coordinates(y-coordinates) of all the points
# are samples from a 1D Gaussian distribution 
# using the estimated mean and variance based on the x-coordinates(y-coordinates) of X.

x = np.random.normal(mean_x,var_x,1000)
y = np.random.normal(mean_y,var_y,1000)
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(x, y, c='r', s=10.0, alpha=0.3, label="1D-Gaussians")
ax.grid()
ax.legend(loc = 0)
# Set x/y axis limits
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
print("What's the different between two distributions?\n\
(1) oval with long axis cross the x-axis with about 60 degree \n\
(2) oval with long axis that vertical to x-axis \n")
print("What cause the different? \nx and y are independent in this case.\n")
# Out:
# Mean of X: 0.010478300142980061
#
# Variance of X: 1.034708922316794
#
# Mean of X: 0.06124546309254784
#
# Variance of X: 5.075328237402045
#
# What's the different between two distributions?
# (1) oval with long axis cross the x-axis with about 60 degree
# (2) oval with long axis that vertical to x-axis
#
# What cause the different?
# x and y are independent in this case.

# %%
# Back to the original X
fig, ax = plt.subplots(figsize=(10, 10))
# c='r', dot color is red
# s=10.0, dot size is 10
# alpha=0.3, dot opacity is 0.3
ax.scatter(X[:,0], X[:,1], c='r', s=10.0, alpha=0.3, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])

# TODO: Plot a line segment with x = [-10, 10]
# and y = 3x + 1 onto the 2D-Gaussian plot.
# The np.linspace() function may be helpful.

x = np.linspace(-10,10,100)
y = 3*x+1
ax.plot(x,y)

# %%
# TODO: Project X onto line y=3x + 1
# and plot the projected points on the 2D space.
# You need to remove this line and assign the projected points to X_proj.

k = 3
b = 1
X_proj = np.ones([1000,2])
X_proj[:,0] = (k*X[:,1]+X[:,0]-k*b)/(k**2+1)
X_proj[:,1] = (k**2*X[:,1]+k*X[:,0]+b)/(k**2+1)

# Here we only plot 30 points to check the correctness
fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(X_proj[:30,0], X_proj[:30,1], c='b', s=10.0, alpha=1.0,label="Projected 2D-Gaussian")
ax.scatter(X[:30,0], X[:30,1], c='r', s=10.0, alpha=1.0, label="2D-Gaussian")
ax.grid()
ax.legend(loc = 0)
ax.set_xlim([-10, 10])
ax.set_ylim([-10, 10])
# You can also add the line from the previous plot for verification.
# Out:
# (-10, 10)

# %%
# TODO: Draw the histogram of the x-coordinates
# of the projected points.
# Are the x-coordinates of the projected points
# samples from some Gaussian distribution?
# If so, estimate the mean and variance.
plt.hist(X_proj[:,0], bins='auto')
print("Answer: Yes, they are from Gaussian distribution.\n")
mean_x = np.mean(X_proj[:,0])
print("Mean of X:",mean_x,"\n")
var_x = np.var(X_proj[:,0])
print("Variance of X:",var_x,"\n")
# Out:
# Answer: Yes, they are from Gaussian distribution.
#
# Mean of X: -0.2805785310579377
#
# Variance of X: 0.5612202950214332
